# %% [markdown]
# # September 23, 2021

# %% [markdown]
# Here's to my first programming course in graduate school! Back in my BS Degree, I was able to learn how to program using Python through the following courses:
# <br>
# <br> Applied Physics 155 (Computational Methods in Physics by Mark Newman)
# <br> Applied Physics 156 (Physics by Computers: Programming Physical Problems using Matematica and C)
# <br>
# <br> I had a brief stint of using Matlab for the early parts of my undergraduate research but I ultimately switched to Python because it's free (so I can do the codes in my dorm). Ever since, I've been using Python and my skills cover the basics and advanced programming, specifically Machine Learning through Tensorflow/Keras. Out of all the courses that I've taken so far, I can say that I had learned the most in these programming classes and to this date, I casually revisit my old codes every now and then. Upon choosing an elective course, I enlisted this class because I really enjoyed my previous programming courses. Looking forward to dive in and learn a lot about Julia!

# %% [markdown]
# ## Getting started with Julia via REPL (Read-Eval-Print Loop)

# %% [markdown]
# For each session, a set of O (Objectives) and KR (Key Results) are given. I will be documenting my experience and the Jupyter notebook files in this repository will serve as my journal.

# %% [markdown]
# <br> O: Successfully Explore Julia
# <br> KR1: Julia can be run using the terminal, the Julia REPL appears
# <br> KR2: Execute via the Julia REPL basic arithmetic expressions such as 2+3, or 3^4
# <br> KR3: Tried several basic mathematical operations such as exponentiation, as well as known functions such as trigonometric and exponents.
# <br> KR4: Switched to the four REPL modes (check the docs for these)
# <br> KR5: Assign a generated 30x30 random matrix via the command rand()
# <br> KR6: Try out other basic tricks in one of the tutorial pages.

# %% [markdown]
# ## KR1

# %% [markdown]
# After succesfully installing Julia, we can now explore Julia REPL and it looks like this. ![KR1.PNG](attachment:KR1.PNG)

# %% [markdown]
# ##  KR2

# %% [markdown]
# ```
#                _
#    _       _ _(_)_     |  Documentation: https://docs.julialang.org
#   (_)     | (_) (_)    |
#    _ _   _| |_  __ _   |  Type "?" for help, "]?" for Pkg help.
#   | | | | | | |/ _` |  |
#   | | |_| | | | (_| |  |  Version 1.6.2 (2021-07-14)
#  _/ |\__'_|_|_|\__'_|  |  Official https://julialang.org/ release
# |__/                   |
#
#
# julia> 2+3
# 5
#
# julia> 3^4
# 81
#
# julia> sin(pi)
# 1.2246467991473532e-16
#
# julia> cos(1)
# 0.5403023058681398
#
# julia>
# ```
